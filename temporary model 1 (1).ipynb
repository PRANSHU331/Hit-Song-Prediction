# %%
import pandas as pd                  #pandas use for data analysis 
import numpy as np                   #numpy numeric python librery
import seaborn as sns                #use in statistical ploting 
import matplotlib.pyplot as plt      #it also use in ploting 
# %matplotlib inline
import math                          # it use for math work


song_data= pd.read_csv("appended_songs.csv")
song_data.head(10)
# Out:
#    Unnamed: 0               Title                  Artist  Top100  \
# 0           0          In The End             Linkin Park       0
# 1           1   Seven Nation Army       The White Stripes       0
# 2           2          By The Way   Red Hot Chili Peppers       0
# 3           3    Bring Me To Life             Evanescence       0
# 4           4         Last Resort              Papa Roach       0
# 5           5         Sex on Fire           Kings of Leon       0
# 6           6     Smooth Criminal          Alien Ant Farm       0
# 7           8          Chop Suey!        System Of A Down       0
# 8           9         Take Me Out         Franz Ferdinand       0
# 9          11  The Kill (Bury Me)  Thirty Seconds To Mars       0
#
#                       URI  Danceability  Energy  Key  Loudness  Mode  \
# 0  7KSjlzDJvwAG0utAYE9Vvg         0.476   0.632    9    -6.217     0
# 1  7i6r9KotUPQg3ozKKgEPIN         0.737   0.463    0    -7.828     1
# ...

# %%
sns.countplot(x="Mode",data=song_data)

# %%
sns.countplot(x="Time_Signature",data=song_data)

# %%
sns.countplot(x="Key",data=song_data)

# %%
print("Numbeer of song in song data :-  "+ str(len(song_data.index)))
# Out:
# Numbeer of song in song data :-  14158

# %%
song_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14158 entries, 0 to 14157
# Data columns (total 18 columns):
# Unnamed: 0          14158 non-null int64
# Title               14158 non-null object
# Artist              14158 non-null object
# Top100              14158 non-null int64
# URI                 14158 non-null object
# Danceability        14158 non-null float64
# Energy              14158 non-null float64
# Key                 14158 non-null int64
# Loudness            14158 non-null float64
# Mode                14158 non-null int64
# Speechiness         14158 non-null float64
# Acousticness        14158 non-null float64
# Instrumentalness    14158 non-null float64
# Liveness            14158 non-null float64
# Valence             14158 non-null float64
# Tempo               14158 non-null float64
# Duration            14158 non-null int64
# Time_Signature      14158 non-null int64
# dtypes: float64(9), int64(6), object(3)
# memory usage: 1.9+ MB

# %%
song_data.isnull()
# Out:
#        Unnamed: 0  Title  Artist  Top100    URI  Danceability  Energy    Key  \
# 0           False  False   False   False  False         False   False  False
# 1           False  False   False   False  False         False   False  False
# 2           False  False   False   False  False         False   False  False
# 3           False  False   False   False  False         False   False  False
# 4           False  False   False   False  False         False   False  False
# ...           ...    ...     ...     ...    ...           ...     ...    ...
# 14153       False  False   False   False  False         False   False  False
# 14154       False  False   False   False  False         False   False  False
# 14155       False  False   False   False  False         False   False  False
# 14156       False  False   False   False  False         False   False  False
# 14157       False  False   False   False  False         False   False  False
#
# ...

# %%
song_data.isnull().sum()
# Out:
# Unnamed: 0          0
# Title               0
# Artist              0
# Top100              0
# URI                 0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Mode                0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Duration            0
# Time_Signature      0
# dtype: int64

# %%
sns.heatmap(song_data.isnull(),cmap="YlGnBu")

# %%
song_data.head(5)
# Out:
#    Unnamed: 0              Title                 Artist  Top100  \
# 0           0         In The End            Linkin Park       0
# 1           1  Seven Nation Army      The White Stripes       0
# 2           2         By The Way  Red Hot Chili Peppers       0
# 3           3   Bring Me To Life            Evanescence       0
# 4           4        Last Resort             Papa Roach       0
#
#                       URI  Danceability  Energy  Key  Loudness  Mode  \
# 0  7KSjlzDJvwAG0utAYE9Vvg         0.476   0.632    9    -6.217     0
# 1  7i6r9KotUPQg3ozKKgEPIN         0.737   0.463    0    -7.828     1
# 2  3ZOEytgrvLwQaqXreDs2Jx         0.618   0.938    9    -3.442     1
# 3  0COqiPhxzoWICwFCS4eZcp         0.331   0.943    4    -3.188     0
# 4  5W8YXBz9MTIDyrpYaCg2Ky         0.589   0.890    4    -3.719     0
#
#    Speechiness  Acousticness  Instrumentalness  Liveness  Valence    Tempo  \
# 0       0.0376      0.165000          0.337000     0.111    0.132  107.961
# ...

# %%
song_data.drop(['Title','Artist','URI'],axis=1 ,inplace=True)
song_data.head(5)
# Out:
#    Unnamed: 0  Top100  Danceability  Energy  Key  Loudness  Mode  Speechiness  \
# 0           0       0         0.476   0.632    9    -6.217     0       0.0376
# 1           1       0         0.737   0.463    0    -7.828     1       0.0792
# 2           2       0         0.618   0.938    9    -3.442     1       0.0456
# 3           3       0         0.331   0.943    4    -3.188     0       0.0698
# 4           4       0         0.589   0.890    4    -3.719     0       0.0603
#
#    Acousticness  Instrumentalness  Liveness  Valence    Tempo  Duration  \
# 0      0.165000          0.337000     0.111    0.132  107.961    184787
# 1      0.008170          0.447000     0.255    0.324  123.881    231733
# 2      0.017900          0.000000     0.167    0.875   91.455    269000
# 3      0.007210          0.000002     0.242    0.296   94.612    235893
# 4      0.000481          0.000820     0.201    0.692   90.598    199907
#
#    Time_Signature
# 0               4
# 1               4
# ...

# %%
sns.countplot(x="Top100",data=song_data)

# %%
X=song_data.drop("Top100",axis=1) #drop Top100 and select all 
y=song_data["Top100"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel=LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
prediction=logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
classification_report(y_test, prediction)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.93      0.92      0.93      3534\n           1       0.63      0.66      0.64       714\n\n    accuracy                           0.88      4248\n   macro avg       0.78      0.79      0.78      4248\nweighted avg       0.88      0.88      0.88      4248\n'

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,prediction)
# Out:
# array([[3261,  273],
#        [ 246,  468]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,prediction)*100
# Out:
# 87.78248587570621
